# %% [markdown]
# ## Etherscan

# %%
import requests
import pandas as pd
import numpy as np


# https://martin-thoma.com/configuration-files-in-python/

import json

with open("../.private/keys.json") as keys_file:
    KEYS = json.load(keys_file)

APIKEY = KEYS['ETHERSCAN']
# Note: don't print the key, or if you do, delete the cell's output
# (cell outputs are saved and can be sent to Github).

# %% [markdown]
# Etherscan endpoint.

# %%
ENDPOINT = 'https://api.etherscan.io/api'

# %% [markdown]
# Here we combine the GET string directly in the URL. It's equivalent to passing the params parameter to requests.

# %%
# https://datagy.io/python-requests-authentication/


def process_args(params):
    queryString = "?"
    for p in params:
        queryString += p.lower() + "=" + params[p] + "&"

    queryString += "apikey=" + APIKEY
    return queryString

def api(params={}):

    url = ENDPOINT + process_args(params)
    print(url)
    return

    response = requests.get(url,
                            headers={
                                'accept': 'application/json',
                                "User-Agent": ""
                            })

    print(response)
    return response


def etherscan(params={}):

    params['apikey'] = APIKEY

    response = requests.get(ENDPOINT,
                            headers={
                                'accept': 'application/json',
                                "User-Agent": ""
                            },
                            params=params)

    print(response)
    return response.json()

# %% [markdown]
# Some interesting addresses to look after.

# %%
# The largest ETH holder according to: https://ethereum-whales.com/
ADDRESS_ETH_WHALE = "0xf584f8728b874a6a5c7a8d4d387c9aae9172d621"

## The largest ETH wallet according to: https://www.whalestats.com/
ADDRESS_WHALEST = "0xca8fa8f0b631ecdb18cda619c4fc9d197c8affca"

# %%
params = {
    'module': 'account',
    'action': 'balance',
    'address': ADDRESS_ETH_WHALE
}

res = etherscan(params)
# Out:
# <Response [200]>

# %%
res # Return the raw bytes of the data payload
# Out:
# {'status': '1', 'message': 'OK', 'result': '4676125710898724186701'}

# %% [markdown]
# The result is in Weis. Let's convert it.
#
# https://etherscan.io/unitconverter

# %%
int(res['result']) / 1000000000000000000
# Out:
# 4676.125710898724

# %% [markdown]
# Now let's get all transactions from the address.

# %%
params = {
    'module': 'account',
    'action': 'txlist',
    'address': ADDRESS_ETH_WHALE,
    # 'blockno': '8000000'
}

res = etherscan(params)
# Out:
# <Response [200]>

# %%
res
# Out:
# {'status': '1',
#  'message': 'OK',
#  'result': [{'blockNumber': '10444385',
#    'timeStamp': '1594552265',
#    'hash': '0x44f45036ac7e1a1fcd5fa34ca06f268a8a9830da457aa202050bfa5e69e834a3',
#    'nonce': '0',
#    'blockHash': '0x1e7a8cb5621050bcdd643f8589673d182d4fe7d20ed8241c86bcea52c5706016',
#    'transactionIndex': '103',
#    'from': '0x7e0b32ae18a99cc745dd1347173f64e9f5b6a83b',
#    'to': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'value': '100000000000000000',
#    'gas': '21000',
#    'gasPrice': '14000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0x',
#    'contractAddress': '',
#    'cumulativeGasUsed': '11903055',
#    'gasUsed': '21000',
#    'confirmations': '5161527',
#    'methodId': '0x',
#    'functionName': ''},
#   {'blockNumber': '11395416',
#    'timeStamp': '1607208468',
#    'hash': '0x05e286085635865118301f4defebd9c05570e16feb52d153077b9d5a18bc2acf',
#    'nonce': '4169',
#    'blockHash': '0x297baeec26b558803dcf77a6b3159802dc31cb0bafaa03829a76405564c224aa',
#    'transactionIndex': '122',
#    'from': '0xdb2cad4f306b47c9b35541988c7656f1bb092e15',
#    'to': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'value': '2990000000000000000',
#    'gas': '300000',
#    'gasPrice': '25000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0x',
#    'contractAddress': '',
#    'cumulativeGasUsed': '11529571',
#    'gasUsed': '21000',
#    'confirmations': '4210496',
#    'methodId': '0x',
#    'functionName': ''},
#   {'blockNumber': '11395608',
#    'timeStamp': '1607211007',
#    'hash': '0x7e0de1e6afa57ad028729f55af21bcb2215e2dc1cceee0fe411c28b62015ecea',
#    'nonce': '0',
#    'blockHash': '0x17c787ec4ffd58959f63de0ae46d822a85fee5ea6c7fb3233aa99c14a61dca82',
#    'transactionIndex': '155',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x93f2a75d771628856f37f256da95e99ea28aafbe',
#    'value': '10250000000000',
#    'gas': '273824',
#    'gasPrice': '20100000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '...',
#    'contractAddress': '',
#    'cumulativeGasUsed': '11825109',
#    'gasUsed': '248931',
#    'confirmations': '4210304',
#    'methodId': '0xfd453a85',
#    'functionName': 'buy(address token,uint256 tokenId,address owner,uint256 selling,uint256 buying,uint256 price,uint256 sellerFee,tuple signature)'},
#   {'blockNumber': '11395617',
#    'timeStamp': '1607211090',
#    'hash': '0x332f884e4b49c944250310ca29e4d1503e452c1e89c75378ee2bbfd75f481776',
#    'nonce': '1',
#    'blockHash': '0x1662750875a3cbadf7fd04160a8bfb9ec192554a8def8f82c0e5060e60df4536',
#    'transactionIndex': '66',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2',
#    'value': '90000000000000000',
#    'gas': '43738',
#    'gasPrice': '24100000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0xd0e30db0',
#    'contractAddress': '',
#    'cumulativeGasUsed': '6427992',
#    'gasUsed': '43738',
#    'confirmations': '4210295',
#    'methodId': '0xd0e30db0',
#    'functionName': 'deposit()'},
#   {'blockNumber': '11395659',
#    'timeStamp': '1607211696',
#    'hash': '0xa895889ce53e9d5a20f99fdfacc1c95a6de818c5d19e87232aec9343bc684dbe',
#    'nonce': '2',
#    'blockHash': '0xc6462033fbe6f34aa092bd0e9f17cdb595fec7f9a84b10cde126cf8626ca509e',
#    'transactionIndex': '43',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#    'value': '100000000000000000',
#    'gas': '166643',
#    'gasPrice': '26000000000',
#    'isError': '1',
#    'txreceipt_status': '0',
#    'input': '...',
#    'contractAddress': '',
#    'cumulativeGasUsed': '2136248',
#    'gasUsed': '23423',
#    'confirmations': '4210253',
#    'methodId': '0x7ff36ab5',
#    'functionName': 'swapExactETHForTokens(uint256 amountOutMin, address[] path, address to, uint256 deadline)'},
#   {'blockNumber': '11395664',
#    'timeStamp': '1607211803',
#    'hash': '0x074b93dd7fa2fe78a2efeac5eba6bc9d0fbbc416d673e5eda3659af760974dc6',
#    'nonce': '3',
#    'blockHash': '0xd87aa223fa2c1dd38be7dc717910f70291f14aea3871bc2720fe74ebc5c22cfa',
#    'transactionIndex': '140',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#    'value': '1000000000000000000',
#    'gas': '249516',
#    'gasPrice': '20000000000',
#    'isError': '1',
#    'txreceipt_status': '0',
#    'input': '...',
#    'contractAddress': '',
#    'cumulativeGasUsed': '8581570',
#    'gasUsed': '33955',
#    'confirmations': '4210248',
#    'methodId': '0x7ff36ab5',
#    'functionName': 'swapExactETHForTokens(uint256 amountOutMin, address[] path, address to, uint256 deadline)'},
#   {'blockNumber': '11395721',
#    'timeStamp': '1607212709',
#    'hash': '0x2f504150908bc21fc5d47a7fcfe3fff33d98189ca3a60ff46d29235e937dddb6',
#    'nonce': '4',
#    'blockHash': '0x3b8ecb9ba70edeed6b04c6ffd619e061c8ca939441847f4a3eb6b4623a75e440',
#    'transactionIndex': '100',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#    'value': '200000000000000000',
#    'gas': '167310',
#    'gasPrice': '18100000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '...',
#    'contractAddress': '',
#    'cumulativeGasUsed': '11303828',
#    'gasUsed': '126498',
#    'confirmations': '4210191',
#    'methodId': '0x7ff36ab5',
#    'functionName': 'swapExactETHForTokens(uint256 amountOutMin, address[] path, address to, uint256 deadline)'},
#   {'blockNumber': '11395723',
#    'timeStamp': '1607212717',
#    'hash': '0xb949ce8a03010dc0d5d704a6003bac2a49169f24d56fdc35d2bf5893c423ea59',
#    'nonce': '5',
#    'blockHash': '0xa49fb1415525544c9186cdd2d36eb86ae1a8bf5c8289018571c26c07043056da',
#    'transactionIndex': '164',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#    'value': '200000000000000000',
#    'gas': '166643',
#    'gasPrice': '18100000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '...',
#    'contractAddress': '',
#    'cumulativeGasUsed': '11373929',
#    'gasUsed': '125902',
#    'confirmations': '4210189',
#    'methodId': '0x7ff36ab5',
#    'functionName': 'swapExactETHForTokens(uint256 amountOutMin, address[] path, address to, uint256 deadline)'},
#   {'blockNumber': '11395857',
#    'timeStamp': '1607214432',
#    'hash': '0xb6a6ca86d87c6acf706d1c7552b3d0b7291dd31ab6ae605cf993a9f93d1750f3',
#    'nonce': '6',
#    'blockHash': '0x8418b722d2e7d796d9c252189459f515530a1c9443593a18373a1ecb641d0ae9',
#    'transactionIndex': '140',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#    'value': '619505980341157040',
#    'gas': '257941',
#    'gasPrice': '31000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '...',
#    'contractAddress': '',
#    'cumulativeGasUsed': '10555728',
#    'gasUsed': '205079',
#    'confirmations': '4210055',
#    'methodId': '0xfb3bdb41',
#    'functionName': 'swapETHForExactTokens(uint256 amountOut, address[] path, address to, uint256 deadline)'},
#   {'blockNumber': '11395872',
#    'timeStamp': '1607214621',
#    'hash': '0xa185d3d6e6329a23c200ed2947161cb5e28f84cb22168a838dc5510c1514b76c',
#    'nonce': '7',
#    'blockHash': '0xe2408655f17c02a8b17dcd6128db054f1366c1cd31fd4e7f7fbd4ced962b16ee',
#    'transactionIndex': '22',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x0f5d2fb29fb7d3cfee444a200298f468908cc942',
#    'value': '0',
#    'gas': '49992',
#    'gasPrice': '29000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0x095ea7b30000000000000000000000007a250d5630b4cf539739df2c5dacb4c659f2488dffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff',
#    'contractAddress': '',
#    'cumulativeGasUsed': '3297914',
#    'gasUsed': '45448',
#    'confirmations': '4210040',
#    'methodId': '0x095ea7b3',
#    'functionName': 'approve(address _spender, uint256 _value)'},
#   {'blockNumber': '11395894',
#    'timeStamp': '1607214829',
#    'hash': '0x295c1b902f580684847e66a1c693d6d71f99f179b5a2bdab18349220f563f17e',
#    'nonce': '8',
#    'blockHash': '0x4b4630508178b6cf179dbd2462f08ead3b43c455934aa8d7cfb8763ea3d5bed3',
#    'transactionIndex': '30',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#    'value': '50000000000000000',
#    'gas': '199749',
#    'gasPrice': '23100000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '',
#    'contractAddress': '',
#    'cumulativeGasUsed': '4372875',
#    'gasUsed': '156092',
#    'confirmations': '4210018',
#    'methodId': '0xf305d719',
#    'functionName': 'addLiquidityETH(address token, uint256 amountTokenDesired, uint256 amountTokenMin, uint256 amountETHMin, address to, uint256 deadline)'},
#   {'blockNumber': '11408868',
#    'timeStamp': '1607386933',
#    'hash': '0xf16b822b465776982aad7492cfa2de2040879f1a7173f6729794acfc63ae0503',
#    'nonce': '9',
#    'blockHash': '0x948114dacdb0a40c6232ae001b7e0aeee2b8116aaf195102db27dd6abbcd67d8',
#    'transactionIndex': '153',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2',
#    'value': '910000000000000000',
#    'gas': '28738',
#    'gasPrice': '39000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0xd0e30db0',
#    'contractAddress': '',
#    'cumulativeGasUsed': '12416208',
#    'gasUsed': '28738',
#    'confirmations': '4197044',
#    'methodId': '0xd0e30db0',
#    'functionName': 'deposit()'},
#   {'blockNumber': '11413601',
#    'timeStamp': '1607450609',
#    'hash': '0x1285c59a2ad147e871e6f7b75ee803af1ab6560d02e31141e938e2af3efc5862',
#    'nonce': '10',
#    'blockHash': '0x7628dd157ca30c201e4cafc38a8b4b991a6a05d7f2ea0a8e9b551c731a3aeef4',
#    'transactionIndex': '105',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2',
#    'value': '0',
#    'gas': '48690',
#    'gasPrice': '55000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0x095ea7b30000000000000000000000007a250d5630b4cf539739df2c5dacb4c659f2488dffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff',
#    'contractAddress': '',
#    'cumulativeGasUsed': '7611731',
#    'gasUsed': '44264',
#    'confirmations': '4192311',
#    'methodId': '0x095ea7b3',
#    'functionName': 'approve(address _spender, uint256 _value)'},
#   {'blockNumber': '11413607',
#    'timeStamp': '1607450642',
#    'hash': '0x2c39895fd7a10f38286e6dffbbe24c2f2556165e561bd1591bb464050f5c868d',
#    'nonce': '11',
#    'blockHash': '0xbaf08fec9caaa45d4a745491b02e554480fb2ad1fea57cd9ea2b0da44ea5cfea',
#    'transactionIndex': '41',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#    'value': '0',
#    'gas': '194673',
#    'gasPrice': '55000000000',
#    'isError': '1',
#    'txreceipt_status': '0',
#    'input': '...',
#    'contractAddress': '',
#    'cumulativeGasUsed': '3745086',
#    'gasUsed': '193616',
#    'confirmations': '4192305',
#    'methodId': '0x38ed1739',
#    'functionName': 'swapExactTokensForTokens(uint256 amountIn, uint256 amountOutMin, address[] path, address to, uint256 deadline)'},
#   {'blockNumber': '11413615',
#    'timeStamp': '1607450694',
#    'hash': '0xd3930a7ea039b660a9a0d77045eb6c6eff72e2435d1e0d9946863caa4bbf1596',
#    'nonce': '12',
#    'blockHash': '0x46d434e7203e38d3d85a9282e10ba8f3ca7d4c097cc128accb0af707c40ee5ac',
#    'transactionIndex': '148',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#    'value': '0',
#    'gas': '221318',
#    'gasPrice': '55000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '...',
#    'contractAddress': '',
#    'cumulativeGasUsed': '10616134',
#    'gasUsed': '151621',
#    'confirmations': '4192297',
#    'methodId': '0x38ed1739',
#    'functionName': 'swapExactTokensForTokens(uint256 amountIn, uint256 amountOutMin, address[] path, address to, uint256 deadline)'},
#   {'blockNumber': '11480258',
#    'timeStamp': '1608335335',
#    'hash': '0x4b31940339b44a6a0d5f7873e14ce9127e4f4190ec5909c1d3eeebdbf74dd7dc',
#    'nonce': '13',
#    'blockHash': '0x8c16fe91cd49171eb8b45306066212eb61049f0e2203ecbd3b7377dc567ca134',
#    'transactionIndex': '116',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2',
#    'value': '600000000000000000',
#    'gas': '43738',
#    'gasPrice': '31000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0xd0e30db0',
#    'contractAddress': '',
#    'cumulativeGasUsed': '10176379',
#    'gasUsed': '43738',
#    'confirmations': '4125654',
#    'methodId': '0xd0e30db0',
#    'functionName': 'deposit()'},
#   {'blockNumber': '11480338',
#    'timeStamp': '1608336384',
#    'hash': '0x66e4e486a00237ea8208b83a10ee0a6685e4dde10590270ddc1777db94e1e09c',
#    'nonce': '14',
#    'blockHash': '0x799860d9e6f0709679bd6323088fa75df80ad5e76ed819936bb89c9f2e0ac691',
#    'transactionIndex': '156',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x7be8076f4ea4a4ad08075c2508e481d6c946d12b',
#    'value': '55000000000000000',
#    'gas': '182132',
#    'gasPrice': '37000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '...',
#    'contractAddress': '',
#    'cumulativeGasUsed': '12462043',
#    'gasUsed': '159687',
#    'confirmations': '4125574',
#    'methodId': '0xab834bab',
#    'functionName': 'atomicMatch_(address[14] addrs, uint256[18] uints, uint8[8] feeMethodsSidesKindsHowToCalls, bytes calldataBuy, bytes calldataSell, bytes replacementPatternBuy, bytes replacementPatternSell, bytes staticExtradataBuy, bytes staticExtradataSell, uint8[2] vs, bytes32[5] rssMetadata)'},
#   {'blockNumber': '11486539',
#    'timeStamp': '1608418888',
#    'hash': '0x8cf6785a99ba0516bc9545060148368b5446e81218a7ae9ee2913655b9a2d8ab',
#    'nonce': '15',
#    'blockHash': '0xca0e343ef485f730ad672c641b10475e8f609af8ddc4f16fe5eb5a653f011c3b',
#    'transactionIndex': '144',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#    'value': '305297507224481061',
#    'gas': '164858',
#    'gasPrice': '33000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '...',
#    'contractAddress': '',
#    'cumulativeGasUsed': '11109934',
#    'gasUsed': '112287',
#    'confirmations': '4119373',
#    'methodId': '0x7ff36ab5',
#    'functionName': 'swapExactETHForTokens(uint256 amountOutMin, address[] path, address to, uint256 deadline)'},
#   {'blockNumber': '11532191',
#    'timeStamp': '1609023866',
#    'hash': '0x04a5bfaea30aabd12126ede330d6637e986a1ca140f35ec7eb6f124c1754df88',
#    'nonce': '8996',
#    'blockHash': '0x0fa33cb0d860e01d3e53797a718dfaccc16dd1477d65fa6db06be88993c82d27',
#    'transactionIndex': '157',
#    'from': '0xdb2cad4f306b47c9b35541988c7656f1bb092e15',
#    'to': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'value': '5146490390000000000',
#    'gas': '300000',
#    'gasPrice': '58000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0x',
#    'contractAddress': '',
#    'cumulativeGasUsed': '9383534',
#    'gasUsed': '21000',
#    'confirmations': '4073721',
#    'methodId': '0x',
#    'functionName': ''},
#   {'blockNumber': '11532230',
#    'timeStamp': '1609024397',
#    'hash': '0x8cbdb3226609ab5106deac76009d5931fbf35b120fa748ffa7c3805a344dc46d',
#    'nonce': '16',
#    'blockHash': '0x3ef34797396c851e6c41830fb3ea08d5d090e9f037a7ae2570156c62e1d03751',
#    'transactionIndex': '98',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x48e56982414b04211f10517808ee1dfb50a13f65',
#    'value': '3000000000000000000',
#    'gas': '50317',
#    'gasPrice': '51000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0x',
#    'contractAddress': '',
#    'cumulativeGasUsed': '8527887',
#    'gasUsed': '33545',
#    'confirmations': '4073682',
#    'methodId': '0x',
#    'functionName': ''},
#   {'blockNumber': '11532238',
#    'timeStamp': '1609024495',
#    'hash': '0xa5efe079602cfe1f18ddedfcb5dbb925d51232a1425367357e7f265e88ece074',
#    'nonce': '17',
#    'blockHash': '0xf80900c0ba86e88693994d7c7fff37c1dffb856734c00fb6b9a8a7805a48806a',
#    'transactionIndex': '103',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x3a41c057afe522509032d92d3b2a2ba92c27a81d',
#    'value': '400000000000000000',
#    'gas': '21000',
#    'gasPrice': '51000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0x',
#    'contractAddress': '',
#    'cumulativeGasUsed': '12348083',
#    'gasUsed': '21000',
#    'confirmations': '4073674',
#    'methodId': '0x',
#    'functionName': ''},
#   {'blockNumber': '11564703',
#    'timeStamp': '1609455094',
#    'hash': '0x70a43f1e530c7934e3272795defca69390a64155cc3d1d1634dfbd52616d763e',
#    'nonce': '18',
#    'blockHash': '0x741cc4e123f596f493446f163ca0039e776891cde5e51264e5506c988b005350',
#    'transactionIndex': '112',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0xcd4ec7b66fbc029c116ba9ffb3e59351c20b5b06',
#    'value': '20705000000000000',
#    'gas': '238003',
#    'gasPrice': '43000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '...',
#    'contractAddress': '',
#    'cumulativeGasUsed': '9745475',
#    'gasUsed': '238003',
#    'confirmations': '4041209',
#    'methodId': '0x9cec6392',
#    'functionName': 'exchange(tuple order,tuple sig,uint256 buyerFee,tuple buyerFeeSig,uint256 amount,address buyer)'},
#   {'blockNumber': '11648655',
#    'timeStamp': '1610566874',
#    'hash': '0x93038954190c1b7221428cd50ef1ee65c5f19f40bb80847a5da91044d71ba2b2',
#    'nonce': '19',
#    'blockHash': '0x880bfb10737902656ddfc6057338cc16c5bc7cff268fc1ce8a83099c29f8e7e8',
#    'transactionIndex': '74',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48',
#    'value': '0',
#    'gas': '55181',
#    'gasPrice': '59000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0x095ea7b30000000000000000000000007a250d5630b4cf539739df2c5dacb4c659f2488dffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff',
#    'contractAddress': '',
#    'cumulativeGasUsed': '4048461',
#    'gasUsed': '49811',
#    'confirmations': '3957257',
#    'methodId': '0x095ea7b3',
#    'functionName': 'approve(address _spender, uint256 _value)'},
#   {'blockNumber': '11648754',
#    'timeStamp': '1610568401',
#    'hash': '0xd031370653ce5471df71c6cee7cf080c5ae7cf933396cb8e316c44f17347e9b9',
#    'nonce': '20',
#    'blockHash': '0x3249e702f385b01ed55ee76e22e5519c6608b8a005ccf305208c4a0d6dc166cb',
#    'transactionIndex': '114',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0xc944e90c64b2c07662a292be6244bdf05cda44a7',
#    'value': '0',
#    'gas': '44130',
#    'gasPrice': '41800000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0x095ea7b3000000000000000000000000f55041e37e12cd407ad00ce2910b8269b01263b90000000000000000000000000000000000000000000000173644e420bed16280',
#    'contractAddress': '',
#    'cumulativeGasUsed': '10349780',
#    'gasUsed': '44130',
#    'confirmations': '3957158',
#    'methodId': '0x095ea7b3',
#    'functionName': 'approve(address _spender, uint256 _value)'},
#   {'blockNumber': '11648758',
#    'timeStamp': '1610568445',
#    'hash': '0x7409dba2dd12a7b150a05bd1e1f8c0e236888d51f2d69b5b95a8a39e5bdb067b',
#    'nonce': '21',
#    'blockHash': '0x1cb87930b370b9ec807c3ccc95d22f8cd18d0e6a5c49a8d71724f50df5f9f396',
#    'transactionIndex': '108',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0xf55041e37e12cd407ad00ce2910b8269b01263b9',
#    'value': '0',
#    'gas': '250000',
#    'gasPrice': '45000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0x026e402b0000000000000000000000007ed9d36539f349808c42187ed4e1753d5947db7a0000000000000000000000000000000000000000000000173644e420bed16280',
#    'contractAddress': '',
#    'cumulativeGasUsed': '9834926',
#    'gasUsed': '103804',
#    'confirmations': '3957154',
#    'methodId': '0x026e402b',
#    'functionName': 'delegate(address miner, uint256 _value)'},
#   {'blockNumber': '11714694',
#    'timeStamp': '1611442705',
#    'hash': '0x4ed0a9b42cb376f7966c80e81c3705645a6fc162c56ea51a3cc2b41351a42c00',
#    'nonce': '22',
#    'blockHash': '0x971a8b281986e5dd9f8bc1317589e422112121922fec7def3b28fad98eccfda9',
#    'transactionIndex': '63',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#    'value': '0',
#    'gas': '155074',
#    'gasPrice': '57000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '...',
#    'contractAddress': '',
#    'cumulativeGasUsed': '4767104',
#    'gasUsed': '134553',
#    'confirmations': '3891218',
#    'methodId': '0x38ed1739',
#    'functionName': 'swapExactTokensForTokens(uint256 amountIn, uint256 amountOutMin, address[] path, address to, uint256 deadline)'},
#   {'blockNumber': '11714785',
#    'timeStamp': '1611443910',
#    'hash': '0x27c9b98d6437182f03672db929a5556bb9fa0a5617696ede99bb2cc711415fc9',
#    'nonce': '23',
#    'blockHash': '0x7bfc538a9a6131800b703775d67c894ddbf53b027eec5c9ec6083d7c17c8092a',
#    'transactionIndex': '85',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#    'value': '0',
#    'gas': '228510',
#    'gasPrice': '52000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '...',
#    'contractAddress': '',
#    'cumulativeGasUsed': '9159016',
#    'gasUsed': '185181',
#    'confirmations': '3891127',
#    'methodId': '0x38ed1739',
#    'functionName': 'swapExactTokensForTokens(uint256 amountIn, uint256 amountOutMin, address[] path, address to, uint256 deadline)'},
#   {'blockNumber': '11714792',
#    'timeStamp': '1611443974',
#    'hash': '0xc81e9a6f811ae2062b0b32a5e5dbcd71eccb62bcd0a3b9a06570fa335ac67605',
#    'nonce': '24',
#    'blockHash': '0x7ce11453f63a46f148ba0c426d38a16dd6fef1332beefc88a0e6087382cecfcb',
#    'transactionIndex': '244',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x4de2573e27e648607b50e1cfff921a33e4a34405',
#    'value': '0',
#    'gas': '49770',
#    'gasPrice': '53000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0x095ea7b30000000000000000000000007a250d5630b4cf539739df2c5dacb4c659f2488dffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff',
#    'contractAddress': '',
#    'cumulativeGasUsed': '12494383',
#    'gasUsed': '45246',
#    'confirmations': '3891120',
#    'methodId': '0x095ea7b3',
#    'functionName': 'approve(address _spender, uint256 _value)'},
#   {'blockNumber': '11714796',
#    'timeStamp': '1611444057',
#    'hash': '0x62ad23f00cec067adeb2fd7ae639bce9b84d8aa9781b16f0ade99350eb1f42c6',
#    'nonce': '25',
#    'blockHash': '0xc61dd139bd76fa510b33ec69d1c0b9bc72e0fca6963fccca4e468ebb8f59ca60',
#    'transactionIndex': '79',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#    'value': '161190539719521422',
#    'gas': '193369',
#    'gasPrice': '55000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '',
#    'contractAddress': '',
#    'cumulativeGasUsed': '5590678',
#    'gasUsed': '135011',
#    'confirmations': '3891116',
#    'methodId': '0xf305d719',
#    'functionName': 'addLiquidityETH(address token, uint256 amountTokenDesired, uint256 amountTokenMin, uint256 amountETHMin, address to, uint256 deadline)'},
#   {'blockNumber': '11715089',
#    'timeStamp': '1611447885',
#    'hash': '0x1b63ebb839990f874029c632b048c14d3b227c8145f13fc3a14a40efcf3fda2f',
#    'nonce': '26',
#    'blockHash': '0xe489696d64b0c2f4024705cd77f7152587236af9cf515ee30adc2dda19b69a92',
#    'transactionIndex': '22',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x6b175474e89094c44da98b954eedeac495271d0f',
#    'value': '0',
#    'gas': '66105',
#    'gasPrice': '65587501000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0x095ea7b3000000000000000000000000fdaa5becfd7a397fa189909419a9caec8096890e00000000000000000000000000000000000000000052b7d2dcc80cd2e4000000',
#    'contractAddress': '',
#    'cumulativeGasUsed': '2953510',
#    'gasUsed': '44070',
#    'confirmations': '3890823',
#    'methodId': '0x095ea7b3',
#    'functionName': 'approve(address _spender, uint256 _value)'},
#   {'blockNumber': '11715116',
#    'timeStamp': '1611448261',
#    'hash': '0xd925a62976545ca4766e3b4942d6732afd3def77c6f6ac8b2af1a269da6d2d0b',
#    'nonce': '27',
#    'blockHash': '0x0ec56b85b40d5fdb82e503f555094676336cabdc8b1dae231fb1f35335a86d82',
#    'transactionIndex': '138',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0xfdaa5becfd7a397fa189909419a9caec8096890e',
#    'value': '0',
#    'gas': '286248',
#    'gasPrice': '65000000000',
#    'isError': '1',
#    'txreceipt_status': '0',
#    'input': '0xc290d69100000000000000000000000000000000000000000000001a589ad90fc7d80000',
#    'contractAddress': '',
#    'cumulativeGasUsed': '8997996',
#    'gasUsed': '25524',
#    'confirmations': '3890796',
#    'methodId': '0xc290d691',
#    'functionName': 'pay(uint256 _invoiceId)'},
#   {'blockNumber': '11715467',
#    'timeStamp': '1611452861',
#    'hash': '0x3026919c6e8c4b00e5781850839581c5a7f14e0e7c80220ca0655dadfbfcfbe1',
#    'nonce': '28',
#    'blockHash': '0xcee07a95edcc55136d89602262bc0989a78d2064b3052985a495019a4458388e',
#    'transactionIndex': '64',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x6b175474e89094c44da98b954eedeac495271d0f',
#    'value': '0',
#    'gas': '66105',
#    'gasPrice': '51000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0x095ea7b3000000000000000000000000adb74ae0a618c0b7474b9f2e7b7cceccf72f967600000000000000000000000000000000000000000052b7d2dcc80cd2e4000000',
#    'contractAddress': '',
#    'cumulativeGasUsed': '3224103',
#    'gasUsed': '44070',
#    'confirmations': '3890445',
#    'methodId': '0x095ea7b3',
#    'functionName': 'approve(address _spender, uint256 _value)'},
#   {'blockNumber': '11715472',
#    'timeStamp': '1611452927',
#    'hash': '0x931851c0bae59b13980f6379a023fc5ce98b33a69401b2e6b8da2709108f62d2',
#    'nonce': '29',
#    'blockHash': '0xd91ab1baf07089cf072880c979fbdd7f3c6697acdbd73064e65947c9d638cdae',
#    'transactionIndex': '183',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0xadb74ae0a618c0b7474b9f2e7b7cceccf72f9676',
#    'value': '0',
#    'gas': '221515',
#    'gasPrice': '51000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0xc290d69100000000000000000000000000000000000000000000001a589ad90fc7d80000',
#    'contractAddress': '',
#    'cumulativeGasUsed': '12379598',
#    'gasUsed': '147677',
#    'confirmations': '3890440',
#    'methodId': '0xc290d691',
#    'functionName': 'pay(uint256 _invoiceId)'},
#   {'blockNumber': '11727597',
#    'timeStamp': '1611613478',
#    'hash': '0x102d1d40fb00875943f48aa124496135180b24660c8e5ff84ea6bf1ea612db92',
#    'nonce': '30',
#    'blockHash': '0xcf4731bbf3ae4c8a3b3b035ee56992eef102541c18668969186fb58b07586e4b',
#    'transactionIndex': '118',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#    'value': '0',
#    'gas': '227374',
#    'gasPrice': '83000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '...',
#    'contractAddress': '',
#    'cumulativeGasUsed': '11778584',
#    'gasUsed': '184170',
#    'confirmations': '3878315',
#    'methodId': '0x8803dbee',
#    'functionName': 'swapTokensForExactTokens(uint256 amountOut, uint256 amountInMax, address[] path, address to, uint256 deadline)'},
#   {'blockNumber': '11730427',
#    'timeStamp': '1611652659',
#    'hash': '0x54934bab82c5cedd8b54c14b5252fd711aa94c59b372390e0386b5988500fa8f',
#    'nonce': '31',
#    'blockHash': '0xd5ed26086d6e16d5ac30611b6e1f19f3938c46e638fb096295aa63c10fe50f45',
#    'transactionIndex': '124',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x9d23cb25ad23d73e0a723a47b146139d46ab5f91',
#    'value': '0',
#    'gas': '65997',
#    'gasPrice': '59845722212',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0x095ea7b3000000000000000000000000f34976159adae214e293cf03d12d20eade658a8c00000000000000000000000000000000000000000052b7d2dcc80cd2e4000000',
#    'contractAddress': '',
#    'cumulativeGasUsed': '10098513',
#    'gasUsed': '43998',
#    'confirmations': '3875485',
#    'methodId': '0x095ea7b3',
#    'functionName': 'approve(address _spender, uint256 _value)'},
#   {'blockNumber': '11731665',
#    'timeStamp': '1611668714',
#    'hash': '0x16768c408289d4f31dab5e37f24b5a6baee4391cd25a4ac12210992199a17f1f',
#    'nonce': '32',
#    'blockHash': '0x93382ebd20d122f36e9097854271098efa666df211350869eff85f93765ad01f',
#    'transactionIndex': '119',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0xf34976159adae214e293cf03d12d20eade658a8c',
#    'value': '0',
#    'gas': '214657',
#    'gasPrice': '55000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0xa694fc3a0000000000000000000000000000000000000000000000081dcea16978615180',
#    'contractAddress': '',
#    'cumulativeGasUsed': '6670403',
#    'gasUsed': '143105',
#    'confirmations': '3874247',
#    'methodId': '0xa694fc3a',
#    'functionName': 'stake(uint256 countryID)'},
#   {'blockNumber': '11752905',
#    'timeStamp': '1611951377',
#    'hash': '0x90fd184f29376e6cf7d0a40a7f625ccc8a173df4fed972924ebaad48f42f588a',
#    'nonce': '33',
#    'blockHash': '0x50d0c2c345059a705ed29e242fc53526daddf2d4015866fd533e157abe8b9dde',
#    'transactionIndex': '73',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0xc4de189abf94c57f396bd4c52ab13b954febefd8',
#    'value': '0',
#    'gas': '48953',
#    'gasPrice': '88000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0x095ea7b30000000000000000000000007a250d5630b4cf539739df2c5dacb4c659f2488dffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff',
#    'contractAddress': '',
#    'cumulativeGasUsed': '4654343',
#    'gasUsed': '44503',
#    'confirmations': '3853007',
#    'methodId': '0x095ea7b3',
#    'functionName': 'approve(address _spender, uint256 _value)'},
#   {'blockNumber': '11752912',
#    'timeStamp': '1611951452',
#    'hash': '0x2be59d11aeea3f350d17ab7f102e5a825ac6f0a02d6384d5751c45e4bfbec73f',
#    'nonce': '34',
#    'blockHash': '0x702ffc99acc7df77983b276b7ea9f1d98d133722a7aab9555e7a0c7f2dc8ca7f',
#    'transactionIndex': '167',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#    'value': '445697499585599107',
#    'gas': '192687',
#    'gasPrice': '88000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '',
#    'contractAddress': '',
#    'cumulativeGasUsed': '11319088',
#    'gasUsed': '134394',
#    'confirmations': '3853000',
#    'methodId': '0xf305d719',
#    'functionName': 'addLiquidityETH(address token, uint256 amountTokenDesired, uint256 amountTokenMin, uint256 amountETHMin, address to, uint256 deadline)'},
#   {'blockNumber': '11752917',
#    'timeStamp': '1611951553',
#    'hash': '0x8472cd8dc59820983ccebca0cfde29174b312fc752b4802a7f52478ba8c9e3d5',
#    'nonce': '35',
#    'blockHash': '0xe735ff6d036e5721afc1b25928d6495136ab0396325f70228827631e9f46c07b',
#    'transactionIndex': '112',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0xe6f51e892046cb5b437e0033d990b527ea4367c8',
#    'value': '0',
#    'gas': '65997',
#    'gasPrice': '88000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0x095ea7b30000000000000000000000003e044de76926a599554701573804699f9e23510700000000000000000000000000000000000000000052b7d2dcc80cd2e4000000',
#    'contractAddress': '',
#    'cumulativeGasUsed': '11130216',
#    'gasUsed': '43998',
#    'confirmations': '3852995',
#    'methodId': '0x095ea7b3',
#    'functionName': 'approve(address _spender, uint256 _value)'},
#   {'blockNumber': '11752942',
#    'timeStamp': '1611951865',
#    'hash': '0x07328fda59ea3750b739f7fe62ca9c30b30b173c738ff8d045e0bd9118178402',
#    'nonce': '36',
#    'blockHash': '0xc8d3a60c28c39e23d7a2463f9f09e868145291a80e3e4c7c95c11e919138110a',
#    'transactionIndex': '100',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x3e044de76926a599554701573804699f9e235107',
#    'value': '0',
#    'gas': '214450',
#    'gasPrice': '70000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0xa694fc3a0000000000000000000000000000000000000000000000014cc1303a7dcc2a80',
#    'contractAddress': '',
#    'cumulativeGasUsed': '9580795',
#    'gasUsed': '142967',
#    'confirmations': '3852970',
#    'methodId': '0xa694fc3a',
#    'functionName': 'stake(uint256 countryID)'},
#   {'blockNumber': '11764332',
#    'timeStamp': '1612103317',
#    'hash': '0xb1afb37a934428e187f2649894a3f9c004bc393b18c1a1dd724c4e72703d3ccc',
#    'nonce': '37',
#    'blockHash': '0x3af6126ddb2e7a12edd0fd0dcf3091056a6b792c30b69fa21c4c9a6d11c4c9fe',
#    'transactionIndex': '60',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x65d103a810099193c892a23d6b320cf3b9e30d46',
#    'value': '0',
#    'gas': '200000',
#    'gasPrice': '120000000000',
#    'isError': '1',
#    'txreceipt_status': '0',
#    'input': '...',
#    'contractAddress': '',
#    'cumulativeGasUsed': '3935347',
#    'gasUsed': '198458',
#    'confirmations': '3841580',
#    'methodId': '0xa949dc3e',
#    'functionName': 'create(address[] _components, int256[] _units, address[] _modules, address _manager, string _name, string _symbol)'},
#   {'blockNumber': '11848388',
#    'timeStamp': '1613220921',
#    'hash': '0x866b664e698097c68e66e1fcabce07a58dde88512cb10b784fb86a6b0eb4836f',
#    'nonce': '38',
#    'blockHash': '0x533e3d9539480202c99f13f054384a0c4829dadef4c1c4ef4f02373559e90505',
#    'transactionIndex': '140',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x3845badade8e6dff049820680d1f14bd3903a5d0',
#    'value': '0',
#    'gas': '44445',
#    'gasPrice': '166350000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0x095ea7b3000000000000000000000000e5c783ee536cf5e63e792988335c4255169be4e1ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff',
#    'contractAddress': '',
#    'cumulativeGasUsed': '8823959',
#    'gasUsed': '44445',
#    'confirmations': '3757524',
#    'methodId': '0x095ea7b3',
#    'functionName': 'approve(address _spender, uint256 _value)'},
#   {'blockNumber': '11848388',
#    'timeStamp': '1613220921',
#    'hash': '0xb62c240cb2d327ac5dbc542368784449f7fd02b1b9b2b5ae6f728657f1130533',
#    'nonce': '39',
#    'blockHash': '0x533e3d9539480202c99f13f054384a0c4829dadef4c1c4ef4f02373559e90505',
#    'transactionIndex': '141',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x3845badade8e6dff049820680d1f14bd3903a5d0',
#    'value': '0',
#    'gas': '44445',
#    'gasPrice': '166350000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0x095ea7b3000000000000000000000000e5c783ee536cf5e63e792988335c4255169be4e1ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff',
#    'contractAddress': '',
#    'cumulativeGasUsed': '8849204',
#    'gasUsed': '25245',
#    'confirmations': '3757524',
#    'methodId': '0x095ea7b3',
#    'functionName': 'approve(address _spender, uint256 _value)'},
#   {'blockNumber': '11848559',
#    'timeStamp': '1613223388',
#    'hash': '0x103869e0679770b20ee3a3c50af0cacbc3484b8eda6d36e715f6bcd22350c50f',
#    'nonce': '0',
#    'blockHash': '0xc29e955d271c8b95b80049d654ca074be9b4dc9695087558f4db99e205b6f436',
#    'transactionIndex': '26',
#    'from': '0xa23041bb940428bb23b9b7ab32bcfcd39cbc5c67',
#    'to': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'value': '1377671850000000000',
#    'gas': '21000',
#    'gasPrice': '208000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0x',
#    'contractAddress': '',
#    'cumulativeGasUsed': '869930',
#    'gasUsed': '21000',
#    'confirmations': '3757353',
#    'methodId': '0x',
#    'functionName': ''},
#   {'blockNumber': '11848591',
#    'timeStamp': '1613223767',
#    'hash': '0x64a8a5151dffcef4796cd96f052f127f65d95fd5487d09f917ab7c109517b5c7',
#    'nonce': '40',
#    'blockHash': '0xc778dc245d1b9eeca4b365e464eb6c367d35e9644fbccec8a05cade24cf6ebdf',
#    'transactionIndex': '97',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x3845badade8e6dff049820680d1f14bd3903a5d0',
#    'value': '0',
#    'gas': '48889',
#    'gasPrice': '146000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0x095ea7b30000000000000000000000007a250d5630b4cf539739df2c5dacb4c659f2488dffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff',
#    'contractAddress': '',
#    'cumulativeGasUsed': '7036758',
#    'gasUsed': '44445',
#    'confirmations': '3757321',
#    'methodId': '0x095ea7b3',
#    'functionName': 'approve(address _spender, uint256 _value)'},
#   {'blockNumber': '11848599',
#    'timeStamp': '1613223823',
#    'hash': '0x159be6f210d2efb161d327093ea895c561c142f4dd2058d64341725a45119ff8',
#    'nonce': '41',
#    'blockHash': '0xe0860155f978a5993897507036059d34f730c05b15dbaee09f3a6ed0f4827a79',
#    'transactionIndex': '95',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#    'value': '2000000000000000000',
#    'gas': '193200',
#    'gasPrice': '134000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '',
#    'contractAddress': '',
#    'cumulativeGasUsed': '3669552',
#    'gasUsed': '150139',
#    'confirmations': '3757313',
#    'methodId': '0xf305d719',
#    'functionName': 'addLiquidityETH(address token, uint256 amountTokenDesired, uint256 amountTokenMin, uint256 amountETHMin, address to, uint256 deadline)'},
#   {'blockNumber': '11848608',
#    'timeStamp': '1613223911',
#    'hash': '0x3893847bf25cefc3796f5aa0648156cb140b070c8ee2e591d5ded3f72be84e82',
#    'nonce': '42',
#    'blockHash': '0xe15709717941d24fd52b80edb70bd27e5651b82c27e55b773080bbdb1428aba8',
#    'transactionIndex': '162',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x3dd49f67e9d5bc4c5e6634b3f70bfd9dc1b6bd74',
#    'value': '0',
#    'gas': '80000',
#    'gasPrice': '111000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0x095ea7b3000000000000000000000000eae6fd7d8c1740f3f1b03e9a5c35793cd260b9a6ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff',
#    'contractAddress': '',
#    'cumulativeGasUsed': '12189844',
#    'gasUsed': '44286',
#    'confirmations': '3757304',
#    'methodId': '0x095ea7b3',
#    'functionName': 'approve(address _spender, uint256 _value)'},
#   {'blockNumber': '11848615',
#    'timeStamp': '1613224004',
#    'hash': '0xb3b801a6ec2b85b00064bc4fc4e943e0c2933576fc5c6c7f15955ea06861ea26',
#    'nonce': '43',
#    'blockHash': '0x14a50d0c5503e83d3783b177abfdf267a53e451715920155d7f363bbaa67f67a',
#    'transactionIndex': '93',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0xeae6fd7d8c1740f3f1b03e9a5c35793cd260b9a6',
#    'value': '0',
#    'gas': '200000',
#    'gasPrice': '103000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0xa694fc3a00000000000000000000000000000000000000000000000906cc5e412adda613',
#    'contractAddress': '',
#    'cumulativeGasUsed': '8201239',
#    'gasUsed': '131240',
#    'confirmations': '3757297',
#    'methodId': '0xa694fc3a',
#    'functionName': 'stake(uint256 countryID)'},
#   {'blockNumber': '11850854',
#    'timeStamp': '1613253828',
#    'hash': '0x12d4a5eb81bd7bae8ecd6d77043b8ee3f2468b67dac73b037890bf955936036c',
#    'nonce': '44',
#    'blockHash': '0xe3ba9c3956191ad6637eccd1b9cab80cbf1a71bbe62c7c43052d98bf2e499b82',
#    'transactionIndex': '168',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x7be8076f4ea4a4ad08075c2508e481d6c946d12b',
#    'value': '280000000000000000',
#    'gas': '182421',
#    'gasPrice': '120000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '...',
#    'contractAddress': '',
#    'cumulativeGasUsed': '12357026',
#    'gasUsed': '174991',
#    'confirmations': '3755058',
#    'methodId': '0xab834bab',
#    'functionName': 'atomicMatch_(address[14] addrs, uint256[18] uints, uint8[8] feeMethodsSidesKindsHowToCalls, bytes calldataBuy, bytes calldataSell, bytes replacementPatternBuy, bytes replacementPatternSell, bytes staticExtradataBuy, bytes staticExtradataSell, uint8[2] vs, bytes32[5] rssMetadata)'},
#   {'blockNumber': '11912719',
#    'timeStamp': '1614075933',
#    'hash': '0xa7df0a52a33450ba283ff3cdcf4a4c628d9cd2a7b2b9be1449d0676017ca80e7',
#    'nonce': '4155728',
#    'blockHash': '0x20152e9c0a5dde3a311c8b4ca839c91817a39cc1038cff2a5d4deb87ce97c78b',
#    'transactionIndex': '35',
#    'from': '0x0681d8db095565fe8a346fa0277bffde9c0edbbf',
#    'to': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'value': '3565540000000000000',
#    'gas': '21000',
#    'gasPrice': '700000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0x',
#    'contractAddress': '',
#    'cumulativeGasUsed': '2572755',
#    'gasUsed': '21000',
#    'confirmations': '3693193',
#    'methodId': '0x',
#    'functionName': ''},
#   {'blockNumber': '11912825',
#    'timeStamp': '1614077429',
#    'hash': '0x53439849621142e0cf2543ad591f6606c506c6803c9a84acaf0f5ea47bf69299',
#    'nonce': '1449651',
#    'blockHash': '0xd9037bbbc909bb4011d6bfee37ee2d447365b3d777370497a4c4e85e6402c6ce',
#    'transactionIndex': '117',
#    'from': '0x46340b20830761efd32832a74d7169b29feb9758',
#    'to': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'value': '1019900000000000000',
#    'gas': '300000',
#    'gasPrice': '600000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0x',
#    'contractAddress': '',
#    'cumulativeGasUsed': '6299807',
#    'gasUsed': '21000',
#    'confirmations': '3693087',
#    'methodId': '0x',
#    'functionName': ''},
#   {'blockNumber': '11935632',
#    'timeStamp': '1614379244',
#    'hash': '0xed246eb8e50c50edc18c91de3d1fe4fdc87611ef2ec84e58ed1e1d451a026736',
#    'nonce': '45',
#    'blockHash': '0xedcf0e5e6f9976f0d13d695d9202b4c3650e5eab9849ed1158288c9c5a319e38',
#    'transactionIndex': '154',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#    'value': '4270000000000000000',
#    'gas': '193211',
#    'gasPrice': '97000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '',
#    'contractAddress': '',
#    'cumulativeGasUsed': '11757353',
#    'gasUsed': '150151',
#    'confirmations': '3670280',
#    'methodId': '0xf305d719',
#    'functionName': 'addLiquidityETH(address token, uint256 amountTokenDesired, uint256 amountTokenMin, uint256 amountETHMin, address to, uint256 deadline)'},
#   {'blockNumber': '11935661',
#    'timeStamp': '1614379659',
#    'hash': '0xe0e295d913bbede17f5c82383d9d49b2a7bf175ff4e3bfaf0bb4588dd1305db7',
#    'nonce': '46',
#    'blockHash': '0x0a359a545e171648257867289e29ccca9774a6281ed458e3d30f9ae32c37a263',
#    'transactionIndex': '124',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0xeae6fd7d8c1740f3f1b03e9a5c35793cd260b9a6',
#    'value': '0',
#    'gas': '200000',
#    'gasPrice': '96800000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0xa694fc3a0000000000000000000000000000000000000000000000104d8566005ed8f10e',
#    'contractAddress': '',
#    'cumulativeGasUsed': '10380630',
#    'gasUsed': '113844',
#    'confirmations': '3670251',
#    'methodId': '0xa694fc3a',
#    'functionName': 'stake(uint256 countryID)'},
#   {'blockNumber': '11940661',
#    'timeStamp': '1614446601',
#    'hash': '0xae66c37c9a97800a4b14f50cde36920f3eb8c80d967900b406564f11d6314909',
#    'nonce': '47',
#    'blockHash': '0x0b6a88dc5992f7d1b66ab0e2cafd1e74d95fe84972388857a5fcc4f508cbc89e',
#    'transactionIndex': '148',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0xf34976159adae214e293cf03d12d20eade658a8c',
#    'value': '0',
#    'gas': '159315',
#    'gasPrice': '83000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0x2e17de780000000000000000000000000000000000000000000000081dcea16978615180',
#    'contractAddress': '',
#    'cumulativeGasUsed': '10215028',
#    'gasUsed': '91210',
#    'confirmations': '3665251',
#    'methodId': '0x2e17de78',
#    'functionName': 'unstake(uint256 amount)'},
#   {'blockNumber': '11942045',
#    'timeStamp': '1614464859',
#    'hash': '0x766ad08d36480f63b8448754c4e3b35ef399568d6db09da98ac657f2bb93adc9',
#    'nonce': '48',
#    'blockHash': '0xf3d2f0419d3172cfc828601c389ef724f528268026af6c86138c007e2c67f619',
#    'transactionIndex': '131',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x9d23cb25ad23d73e0a723a47b146139d46ab5f91',
#    'value': '0',
#    'gas': '65997',
#    'gasPrice': '81000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0x095ea7b30000000000000000000000006b26b8109232b9852c90ead1e0e62fa86a6dacc100000000000000000000000000000000000000000052b7d2dcc80cd2e4000000',
#    'contractAddress': '',
#    'cumulativeGasUsed': '12447988',
#    'gasUsed': '43998',
#    'confirmations': '3663867',
#    'methodId': '0x095ea7b3',
#    'functionName': 'approve(address _spender, uint256 _value)'},
#   {'blockNumber': '11942055',
#    'timeStamp': '1614464947',
#    'hash': '0xfd078c320f2221938cd4cd4cf5c247a8a53c149f179cef47fc4c44bb366c600e',
#    'nonce': '49',
#    'blockHash': '0x9d1b479ace8df71bed65beebe8073ea364c69dc737a1323099bcec1132520fbd',
#    'transactionIndex': '98',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x6b26b8109232b9852c90ead1e0e62fa86a6dacc1',
#    'value': '0',
#    'gas': '214450',
#    'gasPrice': '76000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0xa694fc3a0000000000000000000000000000000000000000000000081dcea16978615180',
#    'contractAddress': '',
#    'cumulativeGasUsed': '6467832',
#    'gasUsed': '142967',
#    'confirmations': '3663857',
#    'methodId': '0xa694fc3a',
#    'functionName': 'stake(uint256 countryID)'},
#   {'blockNumber': '11942083',
#    'timeStamp': '1614465243',
#    'hash': '0xac64b29fd4714ecaecef3fac19b451e819d063c366a5378cc9ed7e8d40e62d27',
#    'nonce': '50',
#    'blockHash': '0xe3d3226018286419dee146def1ac0333e0feb7454f6d3b4343f3cf754551475b',
#    'transactionIndex': '45',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0xf34976159adae214e293cf03d12d20eade658a8c',
#    'value': '0',
#    'gas': '142363',
#    'gasPrice': '79000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0x4e71d92d',
#    'contractAddress': '',
#    'cumulativeGasUsed': '2771794',
#    'gasUsed': '79910',
#    'confirmations': '3663829',
#    'methodId': '0x4e71d92d',
#    'functionName': 'claim()'},
#   {'blockNumber': '12051286',
#    'timeStamp': '1615919467',
# ...
#   {'blockNumber': '12110275',
#    'timeStamp': '1616704134',
#    'hash': '0xef662202db61061871de052a7cb755b1b676a1966af89ca7ef9ebd3b0718ea86',
#    'nonce': '57',
#    'blockHash': '0xf8a2d2614141516ce21d0b1d85238fe1d0ffa92e33dbfb0c12888df6aca44104',
#    'transactionIndex': '240',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x1f9840a85d5af5bf1d1762f925bdaddc4201f984',
#    'value': '0',
#    'gas': '52451',
#    'gasPrice': '133000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0x095ea7b30000000000000000000000000650d780292142835f6ac58dd8e2a336e87b43930000000000000000000000000000000000000000204fce5e30444bad689c0000',
#    'contractAddress': '',
#    'cumulativeGasUsed': '12399540',
#    'gasUsed': '45610',
#    'confirmations': '3495637',
#    'methodId': '0x095ea7b3',
#    'functionName': 'approve(address _spender, uint256 _value)'},
#   {'blockNumber': '12110600',
#    'timeStamp': '1616708071',
#    'hash': '0xd1462747a389d7b6da28336625bb5dae09ac58b28692a8112e4c78c94919443e',
#    'nonce': '58',
#    'blockHash': '0xd0d4666966db4ed0bf18b9745d17f40bc07129288a0f35e083c91e8ac6362fe9',
#    'transactionIndex': '180',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x0650d780292142835f6ac58dd8e2a336e87b4393',
#    'value': '0',
#    'gas': '81000',
#    'gasPrice': '125000000000',
#    'isError': '1',
#    'txreceipt_status': '0',
#    'input': '',
#    'contractAddress': '',
#    'cumulativeGasUsed': '8192724',
#    'gasUsed': '78456',
#    'confirmations': '3495312',
#    'methodId': '0xe323f825',
#    'functionName': 'depositTo(address to, uint256 amount, address controlledToken, address referrer)'},
#   {'blockNumber': '12119641',
#    'timeStamp': '1616827919',
#    'hash': '0x83a4b977e50abccbacfc43fc3a082a33bab680bf67c7adc434c1d6fc2801f846',
#    'nonce': '59',
#    'blockHash': '0x3ba51f54f8536d49b526f7e0649a548d94f7b4bf1e1beb191ec50183742d7b0f',
#    'transactionIndex': '93',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x0650d780292142835f6ac58dd8e2a336e87b4393',
#    'value': '0',
#    'gas': '656356',
#    'gasPrice': '83000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '',
#    'contractAddress': '',
#    'cumulativeGasUsed': '10241023',
#    'gasUsed': '466895',
#    'confirmations': '3486271',
#    'methodId': '0xe323f825',
#    'functionName': 'depositTo(address to, uint256 amount, address controlledToken, address referrer)'},
#   {'blockNumber': '12260397',
#    'timeStamp': '1618699773',
#    'hash': '0x67a90f13ca34d7683264e55412292de1fc321a0697edc5cad64b174aa212347c',
#    'nonce': '60',
#    'blockHash': '0x15f5c01f7d839cf37b2e8514a69f66d044847fab1a9861c0ea7084abfdf8639a',
#    'transactionIndex': '31',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'value': '0',
#    'gas': '21000',
#    'gasPrice': '81070000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0x',
#    'contractAddress': '',
#    'cumulativeGasUsed': '8113924',
#    'gasUsed': '21000',
#    'confirmations': '3345515',
#    'methodId': '0x',
#    'functionName': ''},
#   {'blockNumber': '13888562',
#    'timeStamp': '1640625568',
#    'hash': '0x6d343fe5efe22d0ba3d99856b6f00caff5021929cb476a19adb60322c0a84e41',
#    'nonce': '61',
#    'blockHash': '0x09fb5a2cf946c4bf82040371f7bf02463c422caab7d819548ea7f9a12580bf8d',
#    'transactionIndex': '115',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x3b484b82567a09e2588a13d54d032153f0c0aee0',
#    'value': '0',
#    'gas': '56311',
#    'gasPrice': '117611540373',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0xabf2ebd81c0000000000000000000000000000000000000000030452dd647a9bd1d100007e436407a475ea8a852ffdfc389a677d842bf2f0b335cbe64ec172af719ac92f0e5e2038d05fad077a66d3cf3d25fc2240ca1eae2bdb22ecdf58fd7128305344',
#    'contractAddress': '',
#    'cumulativeGasUsed': '5830159',
#    'gasUsed': '56311',
#    'confirmations': '1717350',
#    'methodId': '0xabf2ebd8',
#    'functionName': 'claim(uint256 amountV, bytes32 r, bytes32 s)'},
#   {'blockNumber': '15009812',
#    'timeStamp': '1655936174',
#    'hash': '0x9819e984746edaf1f3caeb8e231934e363ca8877d40a2f37015caa9b226e69db',
#    'nonce': '62',
#    'blockHash': '0x14b3e039331ccaf6290da7b191be3b25363acdbdc006a6d912a252167a5d24f2',
#    'transactionIndex': '38',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0xeae6fd7d8c1740f3f1b03e9a5c35793cd260b9a6',
#    'value': '0',
#    'gas': '200000',
#    'gasPrice': '24215420724',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0x3d18b912',
#    'contractAddress': '',
#    'cumulativeGasUsed': '2745326',
#    'gasUsed': '60914',
#    'confirmations': '596100',
#    'methodId': '0x3d18b912',
#    'functionName': 'getReward()'},
#   {'blockNumber': '15009834',
#    'timeStamp': '1655936506',
#    'hash': '0x19939b5f27fb461088587db1849acd4973f4dd253c7e3e1a668e1f96dde4db32',
#    'nonce': '63',
#    'blockHash': '0xd94142550840930689b538f6e739ff40d30b07303310033754e8dbaa16a7d7b2',
#    'transactionIndex': '48',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0xeae6fd7d8c1740f3f1b03e9a5c35793cd260b9a6',
#    'value': '0',
#    'gas': '200000',
#    'gasPrice': '34733390704',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0x2e1a7d4d0000000000000000000000000000000000000000000000195451c44189b69721',
#    'contractAddress': '',
#    'cumulativeGasUsed': '4566066',
#    'gasUsed': '85099',
#    'confirmations': '596078',
#    'methodId': '0x2e1a7d4d',
#    'functionName': 'withdraw(uint256 amount)'},
#   {'blockNumber': '15075980',
#    'timeStamp': '1656936762',
#    'hash': '0xf0f83dc8f1a04ace25038bfe531a7ca1540e75a1b716d191d8747b036055c4a6',
#    'nonce': '64',
#    'blockHash': '0x84ff4a88ad18b6742970cb25784df3d7e4a335f3869e306c3979489db51c3cc1',
#    'transactionIndex': '313',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x3845badade8e6dff049820680d1f14bd3903a5d0',
#    'value': '0',
#    'gas': '46545',
#    'gasPrice': '28338534063',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0x095ea7b300000000000000000000000040ec5b33f54e0e8a33a975908c5ba1c14e5bbbdfffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff',
#    'contractAddress': '',
#    'cumulativeGasUsed': '21760105',
#    'gasUsed': '46545',
#    'confirmations': '529932',
#    'methodId': '0x095ea7b3',
#    'functionName': 'approve(address _spender, uint256 _value)'},
#   {'blockNumber': '15082891',
#    'timeStamp': '1657029042',
#    'hash': '0xa60873afacdafdb2fef18126173527520270c1cf4fa2bb1b8dfd005710eff2d2',
#    'nonce': '65',
#    'blockHash': '0x2cde2127c9b3316f1ad392b6d798a2b5bc7d78437b1c38104e9466d22a556238',
#    'transactionIndex': '281',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x3e044de76926a599554701573804699f9e235107',
#    'value': '0',
#    'gas': '150942',
#    'gasPrice': '23377727746',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0xf985021a',
#    'contractAddress': '',
#    'cumulativeGasUsed': '27475364',
#    'gasUsed': '126242',
#    'confirmations': '523021',
#    'methodId': '0xf985021a',
#    'functionName': 'unstakeAndClaim()'},
#   {'blockNumber': '15082947',
#    'timeStamp': '1657029714',
#    'hash': '0x10aa9c19d4d89562b239958ff06b04f7a04b9a5d798311fc9872bcef6b2cb944',
#    'nonce': '66',
#    'blockHash': '0x0f862daffbfde43a2b0f368ddca53f0244044d64dfe86e1c58b405951c9aae20',
#    'transactionIndex': '312',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x6b26b8109232b9852c90ead1e0e62fa86a6dacc1',
#    'value': '0',
#    'gas': '132762',
#    'gasPrice': '33130712296',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0xf985021a',
#    'contractAddress': '',
#    'cumulativeGasUsed': '25109001',
#    'gasUsed': '108062',
#    'confirmations': '522965',
#    'methodId': '0xf985021a',
#    'functionName': 'unstakeAndClaim()'},
#   {'blockNumber': '15101949',
#    'timeStamp': '1657283706',
#    'hash': '0xcd9d79d49a5e9a417fa26344b6264aaf6ab027d6a85f420dabdac169e1fc3981',
#    'nonce': '67',
#    'blockHash': '0xda9b81061b29880b456011ea1e28d7d7ea43e2d1eb69476bbe5e97620de31734',
#    'transactionIndex': '71',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0xa0c68c638235ee32657e8f720a23cec1bfc77c77',
#    'value': '0',
#    'gas': '98966',
#    'gasPrice': '28316448706',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '',
#    'contractAddress': '',
#    'cumulativeGasUsed': '4866629',
#    'gasUsed': '91497',
#    'confirmations': '503963',
#    'methodId': '0xe3dec8fb',
#    'functionName': 'depositFor(address user, address rootToken, bytes depositData)'},
#   {'blockNumber': '15102039',
#    'timeStamp': '1657285043',
#    'hash': '0xf629823a7e4bd220b695c873fb99ffa534e989a5bfe08f227ea14ef159dc3a42',
#    'nonce': '68',
#    'blockHash': '0x4a3fa19da6cf36b6be14cfd1b5040374f3795452536f1559a9468d4bc774ac96',
#    'transactionIndex': '154',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0xa0c68c638235ee32657e8f720a23cec1bfc77c77',
#    'value': '0',
#    'gas': '99002',
#    'gasPrice': '39476093534',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '',
#    'contractAddress': '',
#    'cumulativeGasUsed': '11052920',
#    'gasUsed': '86733',
#    'confirmations': '503873',
#    'methodId': '0xe3dec8fb',
#    'functionName': 'depositFor(address user, address rootToken, bytes depositData)'},
#   {'blockNumber': '15120162',
#    'timeStamp': '1657526861',
#    'hash': '0xfe9352c2d3ded1349370048b85a891d1de31aa6bb0cf141f6184f154a77576b9',
#    'nonce': '69',
#    'blockHash': '0xac99d85eaa69c7b1928941f0c7701fa32d54a57931e2ac8d97d268daea82b2e2',
#    'transactionIndex': '84',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#    'value': '0',
#    'gas': '310107',
#    'gasPrice': '22792983167',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '...',
#    'contractAddress': '',
#    'cumulativeGasUsed': '10877450',
#    'gasUsed': '205088',
#    'confirmations': '485750',
#    'methodId': '0xded9382a',
#    'functionName': 'removeLiquidityETHWithPermit(address token, uint256 liquidity, uint256 amountTokenMin, uint256 amountETHMin, address to, uint256 deadline, bool approveMax, uint8 v, bytes32 r, bytes32 s)'},
#   {'blockNumber': '15120175',
#    'timeStamp': '1657527034',
#    'hash': '0x83b784a4da5396fc78c2f5b16adf209eedbb8b2c7fddef1e010f6b31d62058bd',
#    'nonce': '70',
#    'blockHash': '0x910b11f0ef88d3b348b3f42ca03a562fd5bfd418539ce39ccc331a2f8a196eef',
#    'transactionIndex': '108',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#    'value': '0',
#    'gas': '315334',
#    'gasPrice': '18315759804',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '...',
#    'contractAddress': '',
#    'cumulativeGasUsed': '19370315',
#    'gasUsed': '208573',
#    'confirmations': '485737',
#    'methodId': '0xded9382a',
#    'functionName': 'removeLiquidityETHWithPermit(address token, uint256 liquidity, uint256 amountTokenMin, uint256 amountETHMin, address to, uint256 deadline, bool approveMax, uint8 v, bytes32 r, bytes32 s)'},
#   {'blockNumber': '15120187',
#    'timeStamp': '1657527141',
#    'hash': '0x6e8c3c80bd1d123db73850948cf0b358cfe8087c42c9075b0c415c221bf89ad0',
#    'nonce': '71',
#    'blockHash': '0x6327156fd88590cd1be5ec14f27b2820112962b1429580fedfd2b26f0bfdb564',
#    'transactionIndex': '115',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#    'value': '0',
#    'gas': '311706',
#    'gasPrice': '14807901301',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '...',
#    'contractAddress': '',
#    'cumulativeGasUsed': '9764152',
#    'gasUsed': '206154',
#    'confirmations': '485725',
#    'methodId': '0xded9382a',
#    'functionName': 'removeLiquidityETHWithPermit(address token, uint256 liquidity, uint256 amountTokenMin, uint256 amountETHMin, address to, uint256 deadline, bool approveMax, uint8 v, bytes32 r, bytes32 s)'},
#   {'blockNumber': '15120190',
#    'timeStamp': '1657527187',
#    'hash': '0x429e9019cabfb8c7444b9dfc5e7a199f2f383fc25927536a53ce77ade8209838',
#    'nonce': '72',
#    'blockHash': '0x6bbe163ac9301dc1e7019cd4e95a94cef8883f60cd204ca1f4d6ab2f6c8c531b',
#    'transactionIndex': '85',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#    'value': '0',
#    'gas': '335806',
#    'gasPrice': '15485472420',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '...',
#    'contractAddress': '',
#    'cumulativeGasUsed': '7624814',
#    'gasUsed': '222221',
#    'confirmations': '485722',
#    'methodId': '0xded9382a',
#    'functionName': 'removeLiquidityETHWithPermit(address token, uint256 liquidity, uint256 amountTokenMin, uint256 amountETHMin, address to, uint256 deadline, bool approveMax, uint8 v, bytes32 r, bytes32 s)'},
#   {'blockNumber': '15126672',
#    'timeStamp': '1657612951',
#    'hash': '0x5f30bb535a733092e71e4d81e902dfbaa37ee79ef2066236be7ca22d7e0ad7fb',
#    'nonce': '73',
#    'blockHash': '0xdca902030e7122f497944e9fb0af20eccb28b6eea510f5d8b0b453c51e0bf2ef',
#    'transactionIndex': '166',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0xa0c68c638235ee32657e8f720a23cec1bfc77c77',
#    'value': '0',
#    'gas': '99002',
#    'gasPrice': '16063608336',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '',
#    'contractAddress': '',
#    'cumulativeGasUsed': '15195201',
#    'gasUsed': '86733',
#    'confirmations': '479240',
#    'methodId': '0xe3dec8fb',
#    'functionName': 'depositFor(address user, address rootToken, bytes depositData)'},
#   {'blockNumber': '15127361',
#    'timeStamp': '1657622677',
#    'hash': '0xac8738e048f8cf66516834eced6167796b752347b653d89c435157f8950c8b5d',
#    'nonce': '74',
#    'blockHash': '0x60b7bc39e5078cb884b9eb8aede4cc011c53789a4038efc249e1bfd55d77c783',
#    'transactionIndex': '210',
#    'from': '0xf354eb4b8329f3d4b81e6e3b8fe6bb2df993136d',
#    'to': '0x7e0b32ae18a99cc745dd1347173f64e9f5b6a83b',
#    'value': '20000000000000000000',
#    'gas': '21000',
#    'gasPrice': '10524692068',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '0x',
#    'contractAddress': '',
#    'cumulativeGasUsed': '19079256',
#    'gasUsed': '21000',
#    'confirmations': '478551',
#    'methodId': '0x',
#    'functionName': ''}]}

# %% [markdown]
# There exists also a package to easily interact with the Etherscan API.

# %%
#!pip install etherscan-python
from etherscan import Etherscan
eth = Etherscan(APIKEY)

# %%
eth.get_eth_balance(address=address)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18732/4239317046.py in <module>
# ----> 1 eth.get_eth_balance(address=address)
#
# NameError: name 'eth' is not defined

# %%
eth.get_erc20_token_transfer_events_by_address(address=address)
